# %% [markdown]
# # **Imports and Functions**

# %% [markdown]
# Notebook created by Antoine Carton-Leclercq, PhD
#
# *Tapper Lab, UMass Chan Medical School, Worcester MA*

# %%
import imagej
import os 
import pandas as pd

# Write down Mouse name and folder path
mouse_name = "B2_M3_CTL"
mouse_folder = r"H:\SFC\Images\TRAP_Ai14\B2_M3_CTL"

# REPLACE WITH PREFIX CHOSEN WHEN SAVING ACQUIRED IMAGES Default = Image
prefix = 'Image'

# %%
# Select all folders in the mouse folder
slide_list = os.listdir(mouse_folder)
# Filter out unwanted folders
slide_list = [s for s in slide_list if "Stitched" not in s and "coordinates" not in s]

# Load stitching coordinates
coordinates = pd.read_csv(os.path.join(mouse_folder,f"{mouse_name}_coordinates.csv"))
# Separate rows and columns
all_rows = coordinates.filter(regex = 'rows')
all_cols = coordinates.filter(regex = 'cols')

k=1
for i,slide in enumerate(slide_list):
    print(f"Processing slide {i+1} of {len(slide_list)}: {slide}")
    slices_list = os.listdir(os.path.join(mouse_folder,slide))
    for j,slice in enumerate(slices_list):
        
        print(f"  Processing slice {j+1} of {len(slices_list)}: {slice}")
        temp_folder = os.path.join(mouse_folder,slide,slice)
        print(temp_folder)
# Out:
# Processing slide 1 of 3: S1_2
#   Processing slice 1 of 27: XY01
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY01
#   Processing slice 2 of 27: XY02
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY02
#   Processing slice 3 of 27: XY03
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY03
#   Processing slice 4 of 27: XY04
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY04
#   Processing slice 5 of 27: XY05
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY05
#   Processing slice 6 of 27: XY06
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY06
#   Processing slice 7 of 27: XY07
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY07
#   Processing slice 8 of 27: XY08
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY08
#   Processing slice 9 of 27: XY09
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY09
#   Processing slice 10 of 27: XY10
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY10
#   Processing slice 11 of 27: XY11
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY11
#   Processing slice 12 of 27: XY12
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY12
#   Processing slice 13 of 27: XY13
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY13
#   Processing slice 14 of 27: XY14
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY14
#   Processing slice 15 of 27: XY15
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY15
#   Processing slice 16 of 27: XY16
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY16
#   Processing slice 17 of 27: XY17
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY17
#   Processing slice 18 of 27: XY18
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY18
#   Processing slice 19 of 27: XY19
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY19
#   Processing slice 20 of 27: XY20
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY20
#   Processing slice 21 of 27: XY21
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY21
#   Processing slice 22 of 27: XY22
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY22
#   Processing slice 23 of 27: XY23
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY23
#   Processing slice 24 of 27: XY24
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY24
#   Processing slice 25 of 27: XY25
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY25
#   Processing slice 26 of 27: XY26
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY26
#   Processing slice 27 of 27: XY27
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S1_2\XY27
# Processing slide 2 of 3: S3_4
#   Processing slice 1 of 24: XY01
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY01
#   Processing slice 2 of 24: XY02
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY02
#   Processing slice 3 of 24: XY03
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY03
#   Processing slice 4 of 24: XY04
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY04
#   Processing slice 5 of 24: XY05
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY05
#   Processing slice 6 of 24: XY06
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY06
#   Processing slice 7 of 24: XY07
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY07
#   Processing slice 8 of 24: XY08
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY08
#   Processing slice 9 of 24: XY09
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY09
#   Processing slice 10 of 24: XY10
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY10
#   Processing slice 11 of 24: XY11
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY11
#   Processing slice 12 of 24: XY12
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY12
#   Processing slice 13 of 24: XY13
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY13
#   Processing slice 14 of 24: XY14
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY14
#   Processing slice 15 of 24: XY15
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY15
#   Processing slice 16 of 24: XY16
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY16
#   Processing slice 17 of 24: XY17
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY17
#   Processing slice 18 of 24: XY18
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY18
#   Processing slice 19 of 24: XY19
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY19
#   Processing slice 20 of 24: XY20
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY20
#   Processing slice 21 of 24: XY21
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY21
#   Processing slice 22 of 24: XY22
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY22
#   Processing slice 23 of 24: XY23
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY23
#   Processing slice 24 of 24: XY24
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S3_4\XY24
# Processing slide 3 of 3: S5
#   Processing slice 1 of 3: XY01
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S5\XY01
#   Processing slice 2 of 3: XY02
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S5\XY02
#   Processing slice 3 of 3: XY03
# H:\SFC\Images\TRAP_Ai14\B2_M3_CTL\S5\XY03

# %%
A =os.listdir(temp_folder)[0]

print(A.strip('_'))
# Out:
# Image_XY03.gci

# %%
for x in os.listdir(temp_folder):
    channels = [x.strip('_')[-1]]
# Out:
# ['Image_XY03.gci',
#  'Image_XY03_00001_Z001_CH3.tif',
#  'Image_XY03_00001_Z001_Overlay.tif',
#  'Image_XY03_00002_Z001_CH3.tif',
#  'Image_XY03_00002_Z001_Overlay.tif',
#  'Image_XY03_00003_Z001_CH3.tif',
#  'Image_XY03_00003_Z001_Overlay.tif',
#  'Image_XY03_00004_Z001_CH3.tif',
#  'Image_XY03_00004_Z001_Overlay.tif',
#  'Image_XY03_00005_Z001_CH3.tif',
#  'Image_XY03_00005_Z001_Overlay.tif',
#  'Image_XY03_00006_Z001_CH3.tif',
#  'Image_XY03_00006_Z001_Overlay.tif',
#  'Image_XY03_00007_Z001_CH3.tif',
#  'Image_XY03_00007_Z001_Overlay.tif',
#  'Image_XY03_00008_Z001_CH3.tif',
#  'Image_XY03_00008_Z001_Overlay.tif',
#  'Image_XY03_00009_Z001_CH3.tif',
#  'Image_XY03_00009_Z001_Overlay.tif',
#  'Image_XY03_00010_Z001_CH3.tif',
#  'Image_XY03_00010_Z001_Overlay.tif',
#  'Image_XY03_00011_Z001_CH3.tif',
#  'Image_XY03_00011_Z001_Overlay.tif',
#  'Image_XY03_00012_Z001_CH3.tif',
#  'Image_XY03_00012_Z001_Overlay.tif',
#  'Image_XY03_00013_Z001_CH3.tif',
#  'Image_XY03_00013_Z001_Overlay.tif',
#  'Image_XY03_00014_Z001_CH3.tif',
#  'Image_XY03_00014_Z001_Overlay.tif',
#  'Image_XY03_00015_Z001_CH3.tif',
#  'Image_XY03_00015_Z001_Overlay.tif',
#  'Image_XY03_00016_Z001_CH3.tif',
#  'Image_XY03_00016_Z001_Overlay.tif',
#  'Image_XY03_00017_Z001_CH3.tif',
#  'Image_XY03_00017_Z001_Overlay.tif',
#  'Image_XY03_00018_Z001_CH3.tif',
#  'Image_XY03_00018_Z001_Overlay.tif',
#  'Image_XY03_00019_Z001_CH3.tif',
#  'Image_XY03_00019_Z001_Overlay.tif',
#  'Image_XY03_00020_Z001_CH3.tif',
#  'Image_XY03_00020_Z001_Overlay.tif',
#  'Image_XY03_00021_Z001_CH3.tif',
#  'Image_XY03_00021_Z001_Overlay.tif',
#  'Image_XY03_00022_Z001_CH3.tif',
#  'Image_XY03_00022_Z001_Overlay.tif',
#  'Image_XY03_00023_Z001_CH3.tif',
#  'Image_XY03_00023_Z001_Overlay.tif',
#  'Image_XY03_00024_Z001_CH3.tif',
#  'Image_XY03_00024_Z001_Overlay.tif',
#  'Image_XY03_00025_Z001_CH3.tif',
#  'Image_XY03_00025_Z001_Overlay.tif',
#  'Image_XY03_00026_Z001_CH3.tif',
#  'Image_XY03_00026_Z001_Overlay.tif',
#  'Image_XY03_00027_Z001_CH3.tif',
#  'Image_XY03_00027_Z001_Overlay.tif',
#  'Image_XY03_00028_Z001_CH3.tif',
#  'Image_XY03_00028_Z001_Overlay.tif',
#  'Image_XY03_00029_Z001_CH3.tif',
#  'Image_XY03_00029_Z001_Overlay.tif',
#  'Image_XY03_00030_Z001_CH3.tif',
#  'Image_XY03_00030_Z001_Overlay.tif',
#  'Image_XY03_00031_Z001_CH3.tif',
#  'Image_XY03_00031_Z001_Overlay.tif',
#  'Image_XY03_00032_Z001_CH3.tif',
#  'Image_XY03_00032_Z001_Overlay.tif',
#  'Image_XY03_00033_Z001_CH3.tif',
#  'Image_XY03_00033_Z001_Overlay.tif',
#  'Image_XY03_00034_Z001_CH3.tif',
#  'Image_XY03_00034_Z001_Overlay.tif',
#  'Image_XY03_00035_Z001_CH3.tif',
#  'Image_XY03_00035_Z001_Overlay.tif',
#  'Image_XY03_00036_Z001_CH3.tif',
#  'Image_XY03_00036_Z001_Overlay.tif',
#  'Image_XY03_00037_Z001_CH3.tif',
#  'Image_XY03_00037_Z001_Overlay.tif',
#  'Image_XY03_00038_Z001_CH3.tif',
#  'Image_XY03_00038_Z001_Overlay.tif',
#  'Image_XY03_00039_Z001_CH3.tif',
#  'Image_XY03_00039_Z001_Overlay.tif',
#  'Image_XY03_00040_Z001_CH3.tif',
#  'Image_XY03_00040_Z001_Overlay.tif',
#  'Image_XY03_00041_Z001_CH3.tif',
#  'Image_XY03_00041_Z001_Overlay.tif',
#  'Image_XY03_00042_Z001_CH3.tif',
#  'Image_XY03_00042_Z001_Overlay.tif',
#  'Image_XY03_00043_Z001_CH3.tif',
#  'Image_XY03_00043_Z001_Overlay.tif',
#  'Image_XY03_00044_Z001_CH3.tif',
#  'Image_XY03_00044_Z001_Overlay.tif',
#  'Image_XY03_00045_Z001_CH3.tif',
#  'Image_XY03_00045_Z001_Overlay.tif',
#  'Image_XY03_00046_Z001_CH3.tif',
#  'Image_XY03_00046_Z001_Overlay.tif',
#  'Image_XY03_00047_Z001_CH3.tif',
#  'Image_XY03_00047_Z001_Overlay.tif',
#  'Image_XY03_00048_Z001_CH3.tif',
#  'Image_XY03_00048_Z001_Overlay.tif',
#  'Image_XY03_00049_Z001_CH3.tif',
#  'Image_XY03_00049_Z001_Overlay.tif',
#  'Image_XY03_00050_Z001_CH3.tif',
#  'Image_XY03_00050_Z001_Overlay.tif',
#  'Image_XY03_00051_Z001_CH3.tif',
#  'Image_XY03_00051_Z001_Overlay.tif',
#  'Image_XY03_00052_Z001_CH3.tif',
#  'Image_XY03_00052_Z001_Overlay.tif',
#  'Image_XY03_00053_Z001_CH3.tif',
#  'Image_XY03_00053_Z001_Overlay.tif',
#  'Image_XY03_00054_Z001_CH3.tif',
#  'Image_XY03_00054_Z001_Overlay.tif',
#  'Image_XY03_00055_Z001_CH3.tif',
#  'Image_XY03_00055_Z001_Overlay.tif',
#  'Image_XY03_00056_Z001_CH3.tif',
#  'Image_XY03_00056_Z001_Overlay.tif',
#  'Image_XY03_00057_Z001_CH3.tif',
#  'Image_XY03_00057_Z001_Overlay.tif',
#  'Image_XY03_00058_Z001_CH3.tif',
#  'Image_XY03_00058_Z001_Overlay.tif',
#  'Image_XY03_00059_Z001_CH3.tif',
#  'Image_XY03_00059_Z001_Overlay.tif',
#  'Image_XY03_00060_Z001_CH3.tif',
#  'Image_XY03_00060_Z001_Overlay.tif',
#  'Image_XY03_00061_Z001_CH3.tif',
#  'Image_XY03_00061_Z001_Overlay.tif',
#  'Image_XY03_00062_Z001_CH3.tif',
#  'Image_XY03_00062_Z001_Overlay.tif',
#  'Image_XY03_00063_Z001_CH3.tif',
#  'Image_XY03_00063_Z001_Overlay.tif',
#  'Image_XY03_00064_Z001_CH3.tif',
#  'Image_XY03_00064_Z001_Overlay.tif',
#  'Image_XY03_00065_Z001_CH3.tif',
#  'Image_XY03_00065_Z001_Overlay.tif',
#  'Image_XY03_00066_Z001_CH3.tif',
#  'Image_XY03_00066_Z001_Overlay.tif',
#  'Image_XY03_00067_Z001_CH3.tif',
#  'Image_XY03_00067_Z001_Overlay.tif',
#  'Image_XY03_00068_Z001_CH3.tif',
#  'Image_XY03_00068_Z001_Overlay.tif',
#  'Image_XY03_00069_Z001_CH3.tif',
#  'Image_XY03_00069_Z001_Overlay.tif',
#  'Image_XY03_00070_Z001_CH3.tif',
#  'Image_XY03_00070_Z001_Overlay.tif',
#  'Image_XY03_00071_Z001_CH3.tif',
#  'Image_XY03_00071_Z001_Overlay.tif',
#  'Image_XY03_00072_Z001_CH3.tif',
#  'Image_XY03_00072_Z001_Overlay.tif',
#  'Image_XY03_00073_Z001_CH3.tif',
#  'Image_XY03_00073_Z001_Overlay.tif',
#  'Image_XY03_00074_Z001_CH3.tif',
#  'Image_XY03_00074_Z001_Overlay.tif',
#  'Image_XY03_00075_Z001_CH3.tif',
#  'Image_XY03_00075_Z001_Overlay.tif',
#  'Image_XY03_00076_Z001_CH3.tif',
#  'Image_XY03_00076_Z001_Overlay.tif',
#  'Image_XY03_00077_Z001_CH3.tif',
#  'Image_XY03_00077_Z001_Overlay.tif',
#  'Image_XY03_00078_Z001_CH3.tif',
#  'Image_XY03_00078_Z001_Overlay.tif',
#  'Image_XY03_00079_Z001_CH3.tif',
#  'Image_XY03_00079_Z001_Overlay.tif',
#  'Image_XY03_00080_Z001_CH3.tif',
#  'Image_XY03_00080_Z001_Overlay.tif',
#  'Image_XY03_00081_Z001_CH3.tif',
#  'Image_XY03_00081_Z001_Overlay.tif',
#  'Image_XY03_00082_Z001_CH3.tif',
#  'Image_XY03_00082_Z001_Overlay.tif',
#  'Image_XY03_00083_Z001_CH3.tif',
#  'Image_XY03_00083_Z001_Overlay.tif',
#  'Image_XY03_00084_Z001_CH3.tif',
#  'Image_XY03_00084_Z001_Overlay.tif',
#  'Image_XY03_00085_Z001_CH3.tif',
#  'Image_XY03_00085_Z001_Overlay.tif',
#  'Image_XY03_00086_Z001_CH3.tif',
#  'Image_XY03_00086_Z001_Overlay.tif',
#  'Image_XY03_00087_Z001_CH3.tif',
#  'Image_XY03_00087_Z001_Overlay.tif',
#  'Image_XY03_00088_Z001_CH3.tif',
#  'Image_XY03_00088_Z001_Overlay.tif',
#  'Image_XY03_00089_Z001_CH3.tif',
#  'Image_XY03_00089_Z001_Overlay.tif',
#  'Image_XY03_00090_Z001_CH3.tif',
#  'Image_XY03_00090_Z001_Overlay.tif',
#  'Image_XY03_00091_Z001_CH3.tif',
#  'Image_XY03_00091_Z001_Overlay.tif',
#  'Image_XY03_00092_Z001_CH3.tif',
#  'Image_XY03_00092_Z001_Overlay.tif',
#  'Image_XY03_00093_Z001_CH3.tif',
#  'Image_XY03_00093_Z001_Overlay.tif',
#  'Image_XY03_00094_Z001_CH3.tif',
#  'Image_XY03_00094_Z001_Overlay.tif',
#  'Image_XY03_00095_Z001_CH3.tif',
#  'Image_XY03_00095_Z001_Overlay.tif',
#  'Image_XY03_00096_Z001_CH3.tif',
#  'Image_XY03_00096_Z001_Overlay.tif',
#  'Image_XY03_00097_Z001_CH3.tif',
#  'Image_XY03_00097_Z001_Overlay.tif',
#  'Image_XY03_00098_Z001_CH3.tif',
#  'Image_XY03_00098_Z001_Overlay.tif',
#  'Image_XY03_00099_Z001_CH3.tif',
#  'Image_XY03_00099_Z001_Overlay.tif',
#  'Image_XY03_00100_Z001_CH3.tif',
#  'Image_XY03_00100_Z001_Overlay.tif',
#  'Image_XY03_00101_Z001_CH3.tif',
#  'Image_XY03_00101_Z001_Overlay.tif',
#  'Image_XY03_00102_Z001_CH3.tif',
#  'Image_XY03_00102_Z001_Overlay.tif',
#  'Image_XY03_00103_Z001_CH3.tif',
#  'Image_XY03_00103_Z001_Overlay.tif',
#  'Image_XY03_00104_Z001_CH3.tif',
#  'Image_XY03_00104_Z001_Overlay.tif',
#  'Image_XY03_00105_Z001_CH3.tif',
#  'Image_XY03_00105_Z001_Overlay.tif',
#  'Image_XY03_00106_Z001_CH3.tif',
#  'Image_XY03_00106_Z001_Overlay.tif',
#  'Image_XY03_00107_Z001_CH3.tif',
#  'Image_XY03_00107_Z001_Overlay.tif',
#  'Image_XY03_00108_Z001_CH3.tif',
#  'Image_XY03_00108_Z001_Overlay.tif',
#  'Image_XY03_00109_Z001_CH3.tif',
#  'Image_XY03_00109_Z001_Overlay.tif',
#  'Image_XY03_00110_Z001_CH3.tif',
#  'Image_XY03_00110_Z001_Overlay.tif',
#  'Image_XY03_00111_Z001_CH3.tif',
#  'Image_XY03_00111_Z001_Overlay.tif',
#  'Image_XY03_00112_Z001_CH3.tif',
#  'Image_XY03_00112_Z001_Overlay.tif',
#  'Image_XY03_00113_Z001_CH3.tif',
#  'Image_XY03_00113_Z001_Overlay.tif',
#  'Image_XY03_00114_Z001_CH3.tif',
#  'Image_XY03_00114_Z001_Overlay.tif',
#  'Image_XY03_00115_Z001_CH3.tif',
#  'Image_XY03_00115_Z001_Overlay.tif',
#  'Image_XY03_00116_Z001_CH3.tif',
#  'Image_XY03_00116_Z001_Overlay.tif',
#  'Image_XY03_00117_Z001_CH3.tif',
#  'Image_XY03_00117_Z001_Overlay.tif',
#  'Image_XY03_00118_Z001_CH3.tif',
#  'Image_XY03_00118_Z001_Overlay.tif',
#  'Image_XY03_00119_Z001_CH3.tif',
#  'Image_XY03_00119_Z001_Overlay.tif',
#  'Image_XY03_00120_Z001_CH3.tif',
#  'Image_XY03_00120_Z001_Overlay.tif',
#  'Image_XY03_00121_Z001_CH3.tif',
#  'Image_XY03_00121_Z001_Overlay.tif',
#  'Image_XY03_00122_Z001_CH3.tif',
#  'Image_XY03_00122_Z001_Overlay.tif',
#  'Image_XY03_00123_Z001_CH3.tif',
#  'Image_XY03_00123_Z001_Overlay.tif',
#  'Image_XY03_00124_Z001_CH3.tif',
#  'Image_XY03_00124_Z001_Overlay.tif',
#  'Image_XY03_00125_Z001_CH3.tif',
#  'Image_XY03_00125_Z001_Overlay.tif',
#  'Image_XY03_00126_Z001_CH3.tif',
#  'Image_XY03_00126_Z001_Overlay.tif',
#  'Image_XY03_00127_Z001_CH3.tif',
#  'Image_XY03_00127_Z001_Overlay.tif',
#  'Image_XY03_00128_Z001_CH3.tif',
#  'Image_XY03_00128_Z001_Overlay.tif',
#  'Image_XY03_00129_Z001_CH3.tif',
#  'Image_XY03_00129_Z001_Overlay.tif',
#  'Image_XY03_00130_Z001_CH3.tif',
#  'Image_XY03_00130_Z001_Overlay.tif',
#  'Image_XY03_00131_Z001_CH3.tif',
#  'Image_XY03_00131_Z001_Overlay.tif',
#  'Image_XY03_00132_Z001_CH3.tif',
#  'Image_XY03_00132_Z001_Overlay.tif',
#  'Image_XY03_00133_Z001_CH3.tif',
#  'Image_XY03_00133_Z001_Overlay.tif',
#  'Image_XY03_00134_Z001_CH3.tif',
#  'Image_XY03_00134_Z001_Overlay.tif',
#  'Image_XY03_00135_Z001_CH3.tif',
#  'Image_XY03_00135_Z001_Overlay.tif',
#  'Image_XY03_00136_Z001_CH3.tif',
#  'Image_XY03_00136_Z001_Overlay.tif',
#  'Image_XY03_00137_Z001_CH3.tif',
#  'Image_XY03_00137_Z001_Overlay.tif',
#  'Image_XY03_00138_Z001_CH3.tif',
#  'Image_XY03_00138_Z001_Overlay.tif',
#  'Image_XY03_00139_Z001_CH3.tif',
#  'Image_XY03_00139_Z001_Overlay.tif',
#  'Image_XY03_00140_Z001_CH3.tif',
#  'Image_XY03_00140_Z001_Overlay.tif',
#  'Image_XY03_00141_Z001_CH3.tif',
#  'Image_XY03_00141_Z001_Overlay.tif',
#  'Image_XY03_00142_Z001_CH3.tif',
#  'Image_XY03_00142_Z001_Overlay.tif',
#  'Image_XY03_00143_Z001_CH3.tif',
#  'Image_XY03_00143_Z001_Overlay.tif',
#  'Image_XY03_00144_Z001_CH3.tif',
#  'Image_XY03_00144_Z001_Overlay.tif',
#  'Image_XY03_00145_Z001_CH3.tif',
#  'Image_XY03_00145_Z001_Overlay.tif',
#  'Image_XY03_00146_Z001_CH3.tif',
#  'Image_XY03_00146_Z001_Overlay.tif',
#  'Image_XY03_00147_Z001_CH3.tif',
#  'Image_XY03_00147_Z001_Overlay.tif',
#  'Image_XY03_00148_Z001_CH3.tif',
#  'Image_XY03_00148_Z001_Overlay.tif',
#  'Image_XY03_00149_Z001_CH3.tif',
#  'Image_XY03_00149_Z001_Overlay.tif',
#  'Image_XY03_00150_Z001_CH3.tif',
#  'Image_XY03_00150_Z001_Overlay.tif',
#  'Image_XY03_00151_Z001_CH3.tif',
#  'Image_XY03_00151_Z001_Overlay.tif',
#  'Image_XY03_00152_Z001_CH3.tif',
#  'Image_XY03_00152_Z001_Overlay.tif',
#  'Image_XY03_00153_Z001_CH3.tif',
#  'Image_XY03_00153_Z001_Overlay.tif',
#  'Image_XY03_00154_Z001_CH3.tif',
#  'Image_XY03_00154_Z001_Overlay.tif']

# %% [markdown]
# Insert the path to the Fiji installation folder

# %%
# Initialize ImageJ
ij = imagej.init(r"E:\DATA\QUINT\fiji-latest-win64-jdk\Fiji", headless=False) # Path to FIJI installation FOLDER
print(f"ImageJ2 version: {ij.getVersion()}")

# Define the stitching macro
STITCHING_MACRO = """
#@ String grid_size_x
#@ String grid_size_y
#@ String tile_overlap
#@ String image_path
#@ String image_name
#@ String output_path
#@ String output_filename

run("Grid/Collection stitching",
    "type=[Grid: snake by rows] " +
    "order=[Right & Down                ] " +
    "grid_size_x=" + grid_size_x + " " +
    "grid_size_y=" + grid_size_y + " " +
    "tile_overlap=" + tile_overlap + " " +
    "first_file_index_i=1 " +
    "directory=[" + image_path + "] " +
    "file_names=" + image_name + " " +
    "output_textfile_name=TileConfiguration.txt " +
    "fusion_method=[Linear Blending] " +
    "regression_threshold=0.30 " +
    "max/avg_displacement_threshold=2.50 " +
    "absolute_displacement_threshold=3.50 " +
    "computation_parameters=[Save memory (but be slower)] " +
    "image_output=[Fuse and display]");

// Save the stitched image as TIF
selectWindow("Fused");
saveAs("Tiff", output_path + output_filename);
close();
"""

#---------------------------------------------DETECT CHANNELS -------------------------------------------

def detect_channels(temp_folder):



# ---------------------------------------------STITCHING FUNCTION-------------------------------------------

def stitch_images_with_imagej_macro(temp_folder, output_folder, grid_size_x, grid_size_y, tile_overlap, slice):
    """
    Stitch images using ImageJ Grid/Collection stitching plugin.
    
    Parameters:
    -----------
    temp_folder : str
        Directory containing the input images
    output_folder : str
        Directory where stitched image will be saved
    grid_size_x : int
        Number of columns in the grid
    grid_size_y : int
        Number of rows in the grid
    tile_overlap : int
        Percentage overlap between tiles (typically 10-30%) 
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Convert paths to forward slashes (ImageJ macro compatibility)
    temp_folder_macro = temp_folder.replace('\\', '/')
    output_folder_macro = output_folder.replace('\\', '/')
    
    # Ensure paths end with '/'
    if not temp_folder_macro.endswith('/'):
        temp_folder_macro += '/'
    if not output_folder_macro.endswith('/'):
        output_folder_macro += '/'
    
    # Prepare the macro arguments
    args = {
        "grid_size_x": str(grid_size_x),
        "grid_size_y": str(grid_size_y),
        "tile_overlap": str(tile_overlap),
        "image_path": temp_folder_macro,
        "image_name": f"{prefix}_{slice}"+"_{iiiii}_Z001_Overlay.tif",
        "output_path": output_folder_macro,
        "output_filename": f"{mouse_name}_s{k:04d}.tif"
    }
    
    print(f"Starting stitching with parameters:")
    print(f"  Grid size: {grid_size_x} x {grid_size_y}")
    print(f"  Tile overlap: {tile_overlap}%")
    print(f"  Input directory: {temp_folder_macro}")
    print(f"  Output directory: {output_folder_macro}")
    
    # Run the macro
    ij.py.run_macro(STITCHING_MACRO, args)
    print("Stitching complete!")
# Out:
# The headless flag of imagej.init is deprecated. Use the mode argument instead.
# ImageJ2 version: 2.16.0/1.54p

# %% [markdown]
# # **Stitching**

# %%
# Select all folders in the mouse folder
slide_list = os.listdir(mouse_folder)
# Filter out unwanted folders
slide_list = [s for s in slide_list if "Stitched" not in s and "coordinates" not in s]

# Load stitching coordinates
coordinates = pd.read_csv(os.path.join(mouse_folder,f"{mouse_name}_coordinates.csv"))
# Separate rows and columns
all_rows = coordinates.filter(regex = 'rows')
all_cols = coordinates.filter(regex = 'cols')

k=1
for i,slide in enumerate(slide_list):
    print(f"Processing slide {i+1} of {len(slide_list)}: {slide}")
    slices_list = os.listdir(os.path.join(mouse_folder,slide))
    for j,slice in enumerate(slices_list):
        
        print(f"  Processing slice {j+1} of {len(slices_list)}: {slice}")
        temp_folder = os.path.join(mouse_folder,slide,slice)
        output_folder = os.path.join(mouse_folder,"Stitched")
        
        # Select coordinates for current slide and slice
        col = all_cols.iloc[j,i]
        row = all_rows.iloc[j,i]
        stitch_images_with_imagej_macro(temp_folder, output_folder, grid_size_x=col, grid_size_y=row, tile_overlap=30, slice = slice)
        k+=1
# Out:
# Processing slide 1 of 2: S1_2
#   Processing slice 1 of 29: XY01
# Starting stitching with parameters:
#   Grid size: 14 x 13
#   Tile overlap: 30%
#   Input directory: E:/B2_M4_HC/S1_2/XY01/
#   Output directory: E:/B2_M4_HC/Stitched/
# Stitching complete!
#   Processing slice 2 of 29: XY02
# Starting stitching with parameters:
#   Grid size: 14 x 12
#   Tile overlap: 30%
#   Input directory: E:/B2_M4_HC/S1_2/XY02/
#   Output directory: E:/B2_M4_HC/Stitched/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 25
#      23 col = all_cols.iloc[j,i]
#      24 row = all_rows.iloc[j,i]
# ---> 25 stitch_images_with_imagej_macro(temp_folder, output_folder, grid_size_x=col, grid_size_y=row, tile_overlap=30, slice = slice)
#      26 k+=1
#
# Cell In[5], line 86, in stitch_images_with_imagej_macro(temp_folder, output_folder, grid_size_x, grid_size_y, tile_overlap, slice)
#      83 print(f"  Output directory: {output_folder_macro}")
#      85 # Run the macro
# ---> 86 ij.py.run_macro(STITCHING_MACRO, args)
#      87 print("Stitching complete!")
#
# File c:\Users\cartoa\AppData\Local\anaconda3\envs\stitching\Lib\site-packages\imagej\__init__.py:279, in ImageJPython.run_macro(self, macro, args)
#     274         return self._ij.script().run("macro.ijm", macro, True).get()
#     275     else:
#     276         return (
#     277             self._ij.script()
#     278             .run("macro.ijm", macro, True, self._ij.py.jargs(args))
# --> 279             .get()
#     280         )
#     281 except Exception as exc:
#     282     _log_exception(_logger, exc)
#
# KeyboardInterrupt:

# %% [markdown]
# # **Imports and Functions**

# %% [markdown]
# Notebook created by Antoine Carton-Leclercq, PhD
#
# *Tapper Lab, UMass Chan Medical School, Worcester MA*

# %%
import imagej
import os 
import pandas as pd

# Write down Mouse name and folder path
mouse_name = "NTRP_M1_1"
mouse_folder = r"H:\DATA\Tim\Images\EtOH_Nic\NTRP_M1_1"

# REPLACE WITH PREFIX CHOSEN WHEN SAVING ACQUIRED IMAGES Default = Image
prefix = 'Image'

# %% [markdown]
# Insert the path to the Fiji installation folder

# %%
# Initialize ImageJ
ij = imagej.init(r"E:\DATA\QUINT\fiji-latest-win64-jdk\Fiji", headless=False) # Path to FIJI installation FOLDER
print(f"ImageJ2 version: {ij.getVersion()}")

# Define the stitching macro
STITCHING_MACRO = """
#@ String grid_size_x
#@ String grid_size_y
#@ String tile_overlap
#@ String image_path
#@ String image_name
#@ String output_path
#@ String output_filename

run("Grid/Collection stitching",
    "type=[Grid: snake by rows] " +
    "order=[Right & Down                ] " +
    "grid_size_x=" + grid_size_x + " " +
    "grid_size_y=" + grid_size_y + " " +
    "tile_overlap=" + tile_overlap + " " +
    "first_file_index_i=1 " +
    "directory=[" + image_path + "] " +
    "file_names=" + image_name + " " +
    "output_textfile_name=TileConfiguration.txt " +
    "fusion_method=[Linear Blending] " +
    "regression_threshold=0.30 " +
    "max/avg_displacement_threshold=2.50 " +
    "absolute_displacement_threshold=3.50 " +
    "computation_parameters=[Save memory (but be slower)] " +
    "image_output=[Fuse and display]");

// Save the stitched image as TIF
selectWindow("Fused");
saveAs("Tiff", output_path + output_filename);
close();
"""

#---------------------------------------------DETECT CHANNELS -------------------------------------------

def detect_channels(temp_folder):
    channels = []
    for x in os.listdir(temp_folder):
        if x.endswith('.tif'):
            channel = x.split('_')[-1]
            channel = channel.split('.')[0]
            channels.append(channel)

    res = list(dict.fromkeys(channels))
    return res


# ---------------------------------------------STITCHING FUNCTION-------------------------------------------

def stitch_images_with_imagej_macro(temp_folder, output_folder, grid_size_x, grid_size_y, tile_overlap, channel, slice):
    """
    Stitch images using ImageJ Grid/Collection stitching plugin.
    
    Parameters:
    -----------
    temp_folder : str
        Directory containing the input images
    output_folder : str
        Directory where stitched image will be saved
    grid_size_x : int
        Number of columns in the grid
    grid_size_y : int
        Number of rows in the grid
    tile_overlap : int
        Percentage overlap between tiles (typically 10-30%) 
    channel: str
        Channel to stitch
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Convert paths to forward slashes (ImageJ macro compatibility)
    temp_folder_macro = temp_folder.replace('\\', '/')
    output_folder_macro = output_folder.replace('\\', '/')
    
    # Ensure paths end with '/'
    if not temp_folder_macro.endswith('/'):
        temp_folder_macro += '/'
    if not output_folder_macro.endswith('/'):
        output_folder_macro += '/'
    
    # Prepare the macro arguments
    args = {
        "grid_size_x": str(grid_size_x),
        "grid_size_y": str(grid_size_y),
        "tile_overlap": str(tile_overlap),
        "image_path": temp_folder_macro,
        "image_name": f"{prefix}_{slice}"+"_{iiiii}_Z001_"+f"{channel}.tif",
        "output_path": output_folder_macro,
        "output_filename": f"{mouse_name}_s{k:04d}.tif"
    }
    
    print(f"Starting stitching with parameters:")
    print(f"  Grid size: {grid_size_x} x {grid_size_y}")
    print(f"  Tile overlap: {tile_overlap}%")
    print(f"  Input directory: {temp_folder_macro}")
    print(f"  Output directory: {output_folder_macro}")
    
    # Run the macro
    ij.py.run_macro(STITCHING_MACRO, args)
    print("Stitching complete!")
# Out:
# The headless flag of imagej.init is deprecated. Use the mode argument instead.
# ImageJ2 version: 2.16.0/1.54p

# %% [markdown]
# # **Stitching**

# %% [markdown]
# In this cell all slices will be stitched and saved in an arborescence:
# - Mouse_folder
#     - Stitched
#         - Channel

# %%
# Select all folders in the mouse folder
slide_list = os.listdir(mouse_folder)
# Filter out unwanted folders
slide_list = [s for s in slide_list if "Stitched" not in s and "coordinates" not in s]

# Load stitching coordinates
coordinates = pd.read_csv(os.path.join(mouse_folder,f"{mouse_name}_coordinates.csv"))
# Separate rows and columns
all_rows = coordinates.filter(regex = 'rows')
all_cols = coordinates.filter(regex = 'cols')

k=1
for i,slide in enumerate(slide_list):
    print(f"Processing slide {i+1} of {len(slide_list)}: {slide}")
    slices_list = os.listdir(os.path.join(mouse_folder,slide))
    for j,slice in enumerate(slices_list):
        

        print(f"  Processing slice {j+1} of {len(slices_list)}: {slice}")
        temp_folder = os.path.join(mouse_folder,slide,slice)
        output_folder = os.path.join(mouse_folder,"Stitched")
        if not os.path.exists(output_folder):
            os.mkdir(output_folder)

        # Get list of channels
        channels = detect_channels(temp_folder)
        # Select coordinates for current slide and slice
        col = all_cols.iloc[j,i]
        row = all_rows.iloc[j,i]
        for chan in channels:
            # create arborescence
            output_chan_folder = os.path.join(output_folder,chan)
            
            if not os.path.exists(output_chan_folder):
                os.mkdir(output_chan_folder)
            
            stitch_images_with_imagej_macro(temp_folder, output_chan_folder, grid_size_x=col, grid_size_y=row, tile_overlap=30, channel = chan, slice = slice)
        k+=1
# Out:
# Processing slide 1 of 2: S1_2
#   Processing slice 1 of 32: XY01
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY01/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY01/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY01/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY01/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 2 of 32: XY02
# Starting stitching with parameters:
#   Grid size: 10 x 10
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY02/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 10 x 10
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY02/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 10 x 10
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY02/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 10 x 10
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY02/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 3 of 32: XY03
# Starting stitching with parameters:
#   Grid size: 8 x 13
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY03/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 13
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY03/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 13
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY03/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 13
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY03/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 4 of 32: XY04
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY04/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY04/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY04/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY04/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 5 of 32: XY05
# Starting stitching with parameters:
#   Grid size: 7 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY05/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY05/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY05/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY05/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 6 of 32: XY06
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY06/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY06/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY06/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY06/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 7 of 32: XY07
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY07/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY07/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY07/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY07/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 8 of 32: XY08
# Starting stitching with parameters:
#   Grid size: 9 x 10
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY08/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9 x 10
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY08/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9 x 10
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY08/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9 x 10
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY08/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 9 of 32: XY09
# Starting stitching with parameters:
#   Grid size: 6 x 5
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY09/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6 x 5
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY09/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6 x 5
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY09/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6 x 5
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY09/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 10 of 32: XY10
# Starting stitching with parameters:
#   Grid size: 5 x 8
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY10/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 5 x 8
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY10/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 5 x 8
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY10/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 5 x 8
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY10/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 11 of 32: XY11
# Starting stitching with parameters:
#   Grid size: 8 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY11/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY11/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY11/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY11/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 12 of 32: XY12
# Starting stitching with parameters:
#   Grid size: 8 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY12/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY12/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY12/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY12/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 13 of 32: XY13
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY13/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY13/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY13/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY13/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 14 of 32: XY14
# Starting stitching with parameters:
#   Grid size: 9 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY14/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY14/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY14/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY14/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 15 of 32: XY15
# Starting stitching with parameters:
#   Grid size: 6 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY15/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY15/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY15/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY15/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 16 of 32: XY16
# Starting stitching with parameters:
#   Grid size: 5 x 4
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY16/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 5 x 4
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY16/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 5 x 4
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY16/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 5 x 4
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY16/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 17 of 32: XY17
# Starting stitching with parameters:
#   Grid size: 5 x 7
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY17/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 5 x 7
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY17/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 5 x 7
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY17/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 5 x 7
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY17/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 18 of 32: XY18
# Starting stitching with parameters:
#   Grid size: 6 x 5
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY18/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6 x 5
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY18/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6 x 5
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY18/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6 x 5
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY18/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 19 of 32: XY19
# Starting stitching with parameters:
#   Grid size: 5 x 7
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY19/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 5 x 7
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY19/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 5 x 7
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY19/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 5 x 7
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY19/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 20 of 32: XY20
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY20/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY20/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY20/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 12
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY20/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 21 of 32: XY21
# Starting stitching with parameters:
#   Grid size: 7 x 11
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY21/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7 x 11
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY21/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7 x 11
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY21/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7 x 11
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY21/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 22 of 32: XY22
# Starting stitching with parameters:
#   Grid size: 8 x 13
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY22/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 13
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY22/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 13
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY22/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 13
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY22/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 23 of 32: XY23
# Starting stitching with parameters:
#   Grid size: 8 x 11
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY23/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 11
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY23/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 11
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY23/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 11
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY23/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 24 of 32: XY24
# Starting stitching with parameters:
#   Grid size: 8 x 11
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY24/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 11
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY24/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 11
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY24/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 11
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY24/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 25 of 32: XY25
# Starting stitching with parameters:
#   Grid size: 8 x 10
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY25/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 10
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY25/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 10
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY25/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 10
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY25/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 26 of 32: XY26
# Starting stitching with parameters:
#   Grid size: 9 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY26/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY26/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY26/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY26/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 27 of 32: XY27
# Starting stitching with parameters:
#   Grid size: 8 x 11
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY27/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 11
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY27/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 11
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY27/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8 x 11
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY27/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 28 of 32: XY28
# Starting stitching with parameters:
#   Grid size: 6 x 6
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY28/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6 x 6
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY28/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6 x 6
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY28/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6 x 6
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY28/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 29 of 32: XY29
# Starting stitching with parameters:
#   Grid size: 9 x 11
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY29/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9 x 11
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY29/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9 x 11
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY29/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9 x 11
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY29/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 30 of 32: XY30
# Starting stitching with parameters:
#   Grid size: 6 x 10
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY30/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6 x 10
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY30/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6 x 10
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY30/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6 x 10
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY30/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 31 of 32: XY31
# Starting stitching with parameters:
#   Grid size: 6 x 8
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY31/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6 x 8
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY31/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6 x 8
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY31/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6 x 8
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY31/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 32 of 32: XY32
# Starting stitching with parameters:
#   Grid size: 7 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY32/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY32/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY32/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7 x 9
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S1_2/XY32/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
# Processing slide 2 of 2: S3
#   Processing slice 1 of 16: XY01
# Starting stitching with parameters:
#   Grid size: 8.0 x 12.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY01/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8.0 x 12.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY01/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8.0 x 12.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY01/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8.0 x 12.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY01/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 2 of 16: XY02
# Starting stitching with parameters:
#   Grid size: 9.0 x 13.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY02/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9.0 x 13.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY02/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9.0 x 13.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY02/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9.0 x 13.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY02/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 3 of 16: XY03
# Starting stitching with parameters:
#   Grid size: 9.0 x 13.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY03/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9.0 x 13.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY03/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9.0 x 13.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY03/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9.0 x 13.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY03/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 4 of 16: XY04
# Starting stitching with parameters:
#   Grid size: 6.0 x 9.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY04/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6.0 x 9.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY04/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6.0 x 9.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY04/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6.0 x 9.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY04/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 5 of 16: XY05
# Starting stitching with parameters:
#   Grid size: 6.0 x 9.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY05/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6.0 x 9.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY05/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6.0 x 9.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY05/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 6.0 x 9.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY05/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 6 of 16: XY06
# Starting stitching with parameters:
#   Grid size: 8.0 x 9.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY06/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8.0 x 9.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY06/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8.0 x 9.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY06/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8.0 x 9.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY06/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 7 of 16: XY07
# Starting stitching with parameters:
#   Grid size: 7.0 x 10.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY07/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7.0 x 10.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY07/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7.0 x 10.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY07/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7.0 x 10.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY07/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 8 of 16: XY08
# Starting stitching with parameters:
#   Grid size: 7.0 x 10.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY08/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7.0 x 10.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY08/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7.0 x 10.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY08/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7.0 x 10.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY08/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 9 of 16: XY09
# Starting stitching with parameters:
#   Grid size: 8.0 x 11.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY09/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8.0 x 11.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY09/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8.0 x 11.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY09/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8.0 x 11.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY09/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 10 of 16: XY10
# Starting stitching with parameters:
#   Grid size: 9.0 x 12.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY10/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9.0 x 12.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY10/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9.0 x 12.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY10/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9.0 x 12.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY10/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 11 of 16: XY11
# Starting stitching with parameters:
#   Grid size: 8.0 x 13.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY11/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8.0 x 13.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY11/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8.0 x 13.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY11/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8.0 x 13.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY11/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 12 of 16: XY12
# Starting stitching with parameters:
#   Grid size: 8.0 x 10.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY12/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8.0 x 10.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY12/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8.0 x 10.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY12/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8.0 x 10.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY12/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 13 of 16: XY13
# Starting stitching with parameters:
#   Grid size: 7.0 x 10.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY13/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7.0 x 10.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY13/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7.0 x 10.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY13/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7.0 x 10.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY13/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 14 of 16: XY14
# Starting stitching with parameters:
#   Grid size: 9.0 x 11.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY14/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9.0 x 11.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY14/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9.0 x 11.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY14/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9.0 x 11.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY14/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 15 of 16: XY15
# Starting stitching with parameters:
#   Grid size: 10.0 x 12.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY15/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 10.0 x 12.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY15/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 10.0 x 12.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY15/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 10.0 x 12.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY15/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!
#   Processing slice 16 of 16: XY16
# Starting stitching with parameters:
#   Grid size: 7.0 x 12.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY16/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7.0 x 12.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY16/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH2/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7.0 x 12.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY16/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 7.0 x 12.0
#   Tile overlap: 30%
#   Input directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/S3/XY16/
#   Output directory: H:/DATA/Tim/Images/EtOH_Nic/NTRP_M1_1/Stitched/Overlay/
# Stitching complete!

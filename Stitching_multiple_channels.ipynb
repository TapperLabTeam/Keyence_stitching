# %% [markdown]
# # **Imports and Functions**

# %% [markdown]
# Notebook created by Antoine Carton-Leclercq, PhD
#
# *Tapper Lab, UMass Chan Medical School, Worcester MA*

# %%
import imagej
import os 
import pandas as pd

# Write down Mouse name and folder path
mouse_name = "PNCR6-060126-FA"
mouse_folder = r"F:\rest of PNCR6-060126-FA"

# REPLACE WITH PREFIX CHOSEN WHEN SAVING ACQUIRED IMAGES Default = Image
prefix = 'Image'

# %% [markdown]
# Insert the path to the Fiji installation folder

# %%
# Initialize ImageJ
ij = imagej.init(r"E:\DATA\QUINT\fiji-latest-win64-jdk\Fiji", headless=False) # Path to FIJI installation FOLDER
print(f"ImageJ2 version: {ij.getVersion()}")

# Define the stitching macro
STITCHING_MACRO = """
#@ String grid_size_x
#@ String grid_size_y
#@ String tile_overlap
#@ String image_path
#@ String image_name
#@ String output_path
#@ String output_filename

run("Grid/Collection stitching",
    "type=[Grid: snake by rows] " +
    "order=[Right & Down                ] " +
    "grid_size_x=" + grid_size_x + " " +
    "grid_size_y=" + grid_size_y + " " +
    "tile_overlap=" + tile_overlap + " " +
    "first_file_index_i=1 " +
    "directory=[" + image_path + "] " +
    "file_names=" + image_name + " " +
    "output_textfile_name=TileConfiguration.txt " +
    "fusion_method=[Linear Blending] " +
    "regression_threshold=0.30 " +
    "max/avg_displacement_threshold=2.50 " +
    "absolute_displacement_threshold=3.50 " +
    "computation_parameters=[Save memory (but be slower)] " +
    "image_output=[Fuse and display]");

// Save the stitched image as TIF
selectWindow("Fused");
saveAs("Tiff", output_path + output_filename);
close();
"""

#---------------------------------------------DETECT CHANNELS -------------------------------------------

def detect_channels(temp_folder):
    channels = []
    for x in os.listdir(temp_folder):
        if x.endswith('.tif'):
            channel = x.split('_')[-1]
            channel = channel.split('.')[0]
            channels.append(channel)

    res = list(dict.fromkeys(channels))
    return res


# ---------------------------------------------STITCHING FUNCTION-------------------------------------------

def stitch_images_with_imagej_macro(temp_folder, output_folder, grid_size_x, grid_size_y, tile_overlap, channel, slice):
    """
    Stitch images using ImageJ Grid/Collection stitching plugin.
    
    Parameters:
    -----------
    temp_folder : str
        Directory containing the input images
    output_folder : str
        Directory where stitched image will be saved
    grid_size_x : int
        Number of columns in the grid
    grid_size_y : int
        Number of rows in the grid
    tile_overlap : int
        Percentage overlap between tiles (typically 10-30%) 
    channel: str
        Channel to stitch
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Convert paths to forward slashes (ImageJ macro compatibility)
    temp_folder_macro = temp_folder.replace('\\', '/')
    output_folder_macro = output_folder.replace('\\', '/')
    
    # Ensure paths end with '/'
    if not temp_folder_macro.endswith('/'):
        temp_folder_macro += '/'
    if not output_folder_macro.endswith('/'):
        output_folder_macro += '/'
    
    # Prepare the macro arguments
    args = {
        "grid_size_x": str(grid_size_x),
        "grid_size_y": str(grid_size_y),
        "tile_overlap": str(tile_overlap),
        "image_path": temp_folder_macro,
        "image_name": f"{prefix}_{slice}"+"_{iiiii}_Z001_"+f"{channel}.tif",
        "output_path": output_folder_macro,
        "output_filename": f"{mouse_name}_s{k:04d}.tif"
    }
    
    print(f"Starting stitching with parameters:")
    print(f"  Grid size: {grid_size_x} x {grid_size_y}")
    print(f"  Tile overlap: {tile_overlap}%")
    print(f"  Input directory: {temp_folder_macro}")
    print(f"  Output directory: {output_folder_macro}")
    
    # Run the macro
    ij.py.run_macro(STITCHING_MACRO, args)
    print("Stitching complete!")
# Out:
# The headless flag of imagej.init is deprecated. Use the mode argument instead.
# ImageJ2 version: 2.16.0/1.54p

# %% [markdown]
# # **Stitching**

# %% [markdown]
# In this cell all slices will be stitched and saved in an arborescence:
# - Mouse_folder
#     - Stitched
#         - Channel

# %%
# Select all folders in the mouse folder
slide_list = os.listdir(mouse_folder)
# Filter out unwanted folders
slide_list = [s for s in slide_list if "Stitched" not in s and "coordinates" not in s]
slide_list = sorted(slide_list)



# Load stitching coordinates
coordinates = pd.read_csv(os.path.join(mouse_folder,f"{mouse_name}_coordinates.csv"))
# Separate rows and columns
all_rows = coordinates.filter(regex = 'rows')
all_cols = coordinates.filter(regex = 'cols')

k=1
for i,slide in enumerate(slide_list):
    print(f"Processing slide {i+1} of {len(slide_list)}: {slide}")
    if " " in slide:
        print("/!\ ERROR /!\ : There is a spae in the name of folders preventing sorting")

    slices_list = os.listdir(os.path.join(mouse_folder,slide))
    for j,slice in enumerate(slices_list):
        

        print(f"  Processing slice {j+1} of {len(slices_list)}: {slice}")
        temp_folder = os.path.join(mouse_folder,slide,slice)
        output_folder = os.path.join(mouse_folder,"Stitched")
        if not os.path.exists(output_folder):
            os.mkdir(output_folder)

        # Get list of channels
        channels = detect_channels(temp_folder)
        # Select coordinates for current slide and slice
        col = all_cols.iloc[j,i]
        
        row = all_rows.iloc[j,i]
        print(f"{col}/{row}")
        for chan in channels:
            # create arborescence
            output_chan_folder = os.path.join(output_folder,chan)
            
            if not os.path.exists(output_chan_folder):
                os.mkdir(output_chan_folder)
            
            stitch_images_with_imagej_macro(temp_folder, output_chan_folder, grid_size_x=col, grid_size_y=row, tile_overlap=30, channel = chan, slice = slice)
        k+=1
# Out:
# Processing slide 1 of 4: sld_1
#   Processing slice 1 of 18: XY01
# 11/10
# Starting stitching with parameters:
#   Grid size: 11 x 10
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY01/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 11 x 10
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY01/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 11 x 10
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY01/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 2 of 18: XY02
# 12/11
# Starting stitching with parameters:
#   Grid size: 12 x 11
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY02/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 12 x 11
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY02/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 12 x 11
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY02/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 3 of 18: XY03
# 12/12
# Starting stitching with parameters:
#   Grid size: 12 x 12
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY03/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 12 x 12
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY03/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 12 x 12
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY03/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 4 of 18: XY04
# 13/11
# Starting stitching with parameters:
#   Grid size: 13 x 11
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY04/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 13 x 11
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY04/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 13 x 11
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY04/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 5 of 18: XY05
# 13/12
# Starting stitching with parameters:
#   Grid size: 13 x 12
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY05/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 13 x 12
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY05/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 13 x 12
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY05/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 6 of 18: XY06
# 14/12
# Starting stitching with parameters:
#   Grid size: 14 x 12
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY06/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 14 x 12
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY06/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 14 x 12
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY06/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 7 of 18: XY07
# 14/13
# Starting stitching with parameters:
#   Grid size: 14 x 13
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY07/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 14 x 13
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY07/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 14 x 13
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY07/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 8 of 18: XY08
# 15/13
# Starting stitching with parameters:
#   Grid size: 15 x 13
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY08/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 15 x 13
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY08/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 15 x 13
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY08/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 9 of 18: XY09
# 15/14
# Starting stitching with parameters:
#   Grid size: 15 x 14
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY09/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 15 x 14
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY09/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 15 x 14
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY09/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 10 of 18: XY10
# 15/13
# Starting stitching with parameters:
#   Grid size: 15 x 13
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY10/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 15 x 13
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY10/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 15 x 13
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY10/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 11 of 18: XY11
# 15/14
# Starting stitching with parameters:
#   Grid size: 15 x 14
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY11/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 15 x 14
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY11/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 15 x 14
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY11/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 12 of 18: XY12
# 16/14
# Starting stitching with parameters:
#   Grid size: 16 x 14
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY12/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 16 x 14
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY12/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 16 x 14
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY12/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 13 of 18: XY13
# 16/14
# Starting stitching with parameters:
#   Grid size: 16 x 14
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY13/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 16 x 14
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY13/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 16 x 14
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY13/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 14 of 18: XY14
# 16/15
# Starting stitching with parameters:
#   Grid size: 16 x 15
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY14/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 16 x 15
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY14/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 16 x 15
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY14/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 15 of 18: XY15
# 17/15
# Starting stitching with parameters:
#   Grid size: 17 x 15
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY15/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 17 x 15
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY15/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 17 x 15
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY15/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 16 of 18: XY16
# 17/15
# Starting stitching with parameters:
#   Grid size: 17 x 15
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY16/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 17 x 15
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY16/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 17 x 15
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY16/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 17 of 18: XY17
# 18/16
# Starting stitching with parameters:
#   Grid size: 18 x 16
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY17/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 18 x 16
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY17/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 18 x 16
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY17/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 18 of 18: XY18
# 18/16
# Starting stitching with parameters:
#   Grid size: 18 x 16
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY18/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 18 x 16
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY18/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 18 x 16
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_1/XY18/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
# Processing slide 2 of 4: sld_2
#   Processing slice 1 of 12: XY01
# 17.0/17.0
# Starting stitching with parameters:
#   Grid size: 17.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY01/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 17.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY01/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 17.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY01/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 2 of 12: XY02
# 17.0/17.0
# Starting stitching with parameters:
#   Grid size: 17.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY02/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 17.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY02/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 17.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY02/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 3 of 12: XY03
# 18.0/17.0
# Starting stitching with parameters:
#   Grid size: 18.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY03/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 18.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY03/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 18.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY03/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 4 of 12: XY04
# 19.0/17.0
# Starting stitching with parameters:
#   Grid size: 19.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY04/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 19.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY04/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 19.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY04/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 5 of 12: XY05
# 19.0/17.0
# Starting stitching with parameters:
#   Grid size: 19.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY05/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 19.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY05/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 19.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY05/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 6 of 12: XY06
# 20.0/17.0
# Starting stitching with parameters:
#   Grid size: 20.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY06/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 20.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY06/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 20.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY06/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 7 of 12: XY07
# 19.0/18.0
# Starting stitching with parameters:
#   Grid size: 19.0 x 18.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY07/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 19.0 x 18.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY07/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 19.0 x 18.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY07/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 8 of 12: XY08
# 19.0/17.0
# Starting stitching with parameters:
#   Grid size: 19.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY08/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 19.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY08/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 19.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY08/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 9 of 12: XY09
# 19.0/17.0
# Starting stitching with parameters:
#   Grid size: 19.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY09/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 19.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY09/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 19.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY09/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 10 of 12: XY10
# 19.0/18.0
# Starting stitching with parameters:
#   Grid size: 19.0 x 18.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY10/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 19.0 x 18.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY10/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 19.0 x 18.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY10/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 11 of 12: XY11
# 20.0/17.0
# Starting stitching with parameters:
#   Grid size: 20.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY11/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 20.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY11/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 20.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY11/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 12 of 12: XY12
# 19.0/17.0
# Starting stitching with parameters:
#   Grid size: 19.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY12/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 19.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY12/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 19.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_2/XY12/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
# Processing slide 3 of 4: sld_3
#   Processing slice 1 of 10: XY01
# 20.0/17.0
# Starting stitching with parameters:
#   Grid size: 20.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY01/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 20.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY01/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 20.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY01/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 2 of 10: XY02
# 20.0/18.0
# Starting stitching with parameters:
#   Grid size: 20.0 x 18.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY02/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 20.0 x 18.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY02/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 20.0 x 18.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY02/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 3 of 10: XY03
# 20.0/17.0
# Starting stitching with parameters:
#   Grid size: 20.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY03/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 20.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY03/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 20.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY03/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 4 of 10: XY04
# 15.0/17.0
# Starting stitching with parameters:
#   Grid size: 15.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY04/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 15.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY04/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 15.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY04/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 5 of 10: XY05
# 20.0/17.0
# Starting stitching with parameters:
#   Grid size: 20.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY05/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 20.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY05/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 20.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY05/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 6 of 10: XY06
# 15.0/15.0
# Starting stitching with parameters:
#   Grid size: 15.0 x 15.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY06/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 15.0 x 15.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY06/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 15.0 x 15.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY06/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 7 of 10: XY07
# 19.0/16.0
# Starting stitching with parameters:
#   Grid size: 19.0 x 16.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY07/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 19.0 x 16.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY07/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 19.0 x 16.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY07/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 8 of 10: XY08
# 19.0/16.0
# Starting stitching with parameters:
#   Grid size: 19.0 x 16.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY08/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 19.0 x 16.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY08/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 19.0 x 16.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY08/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 9 of 10: XY09
# 18.0/16.0
# Starting stitching with parameters:
#   Grid size: 18.0 x 16.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY09/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 18.0 x 16.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY09/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 18.0 x 16.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY09/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 10 of 10: XY10
# 14.0/16.0
# Starting stitching with parameters:
#   Grid size: 14.0 x 16.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY10/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 14.0 x 16.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY10/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 14.0 x 16.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_3/XY10/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
# Processing slide 4 of 4: sld_4
#   Processing slice 1 of 15: XY01
# 14.0/17.0
# Starting stitching with parameters:
#   Grid size: 14.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY01/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 14.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY01/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 14.0 x 17.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY01/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 2 of 15: XY02
# 8.0/13.0
# Starting stitching with parameters:
#   Grid size: 8.0 x 13.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY02/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8.0 x 13.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY02/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 8.0 x 13.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY02/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 3 of 15: XY03
# 9.0/14.0
# Starting stitching with parameters:
#   Grid size: 9.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY03/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY03/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 9.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY03/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 4 of 15: XY04
# 12.0/14.0
# Starting stitching with parameters:
#   Grid size: 12.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY04/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 12.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY04/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 12.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY04/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 5 of 15: XY05
# 11.0/14.0
# Starting stitching with parameters:
#   Grid size: 11.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY05/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 11.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY05/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 11.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY05/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 6 of 15: XY06
# 12.0/14.0
# Starting stitching with parameters:
#   Grid size: 12.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY06/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 12.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY06/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 12.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY06/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 7 of 15: XY07
# 16.0/15.0
# Starting stitching with parameters:
#   Grid size: 16.0 x 15.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY07/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 16.0 x 15.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY07/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 16.0 x 15.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY07/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 8 of 15: XY08
# 16.0/15.0
# Starting stitching with parameters:
#   Grid size: 16.0 x 15.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY08/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 16.0 x 15.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY08/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 16.0 x 15.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY08/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 9 of 15: XY09
# 16.0/14.0
# Starting stitching with parameters:
#   Grid size: 16.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY09/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 16.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY09/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 16.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY09/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 10 of 15: XY10
# 16.0/15.0
# Starting stitching with parameters:
#   Grid size: 16.0 x 15.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY10/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 16.0 x 15.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY10/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 16.0 x 15.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY10/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 11 of 15: XY11
# 16.0/15.0
# Starting stitching with parameters:
#   Grid size: 16.0 x 15.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY11/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 16.0 x 15.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY11/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 16.0 x 15.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY11/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 12 of 15: XY12
# 16.0/13.0
# Starting stitching with parameters:
#   Grid size: 16.0 x 13.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY12/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 16.0 x 13.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY12/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 16.0 x 13.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY12/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 13 of 15: XY13
# 17.0/14.0
# Starting stitching with parameters:
#   Grid size: 17.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY13/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 17.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY13/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 17.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY13/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 14 of 15: XY14
# 17.0/14.0
# Starting stitching with parameters:
#   Grid size: 17.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY14/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 17.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY14/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 17.0 x 14.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY14/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!
#   Processing slice 15 of 15: XY15
# 12.0/13.0
# Starting stitching with parameters:
#   Grid size: 12.0 x 13.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY15/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH1/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 12.0 x 13.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY15/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/CH3/
# Stitching complete!
# Starting stitching with parameters:
#   Grid size: 12.0 x 13.0
#   Tile overlap: 30%
#   Input directory: F:/rest of PNCR6-060126-FA/sld_4/XY15/
#   Output directory: F:/rest of PNCR6-060126-FA/Stitched/Overlay/
# Stitching complete!

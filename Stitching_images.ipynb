# %% [markdown]
# # **Imports and Functions**

# %% [markdown]
# Notebook created by Antoine Carton-Leclercq, PhD
#
# *Tapper Lab, UMass Chan Medical School, Worcester MA*

# %%
import imagej
import os 
import pandas as pd

# Write down Mouse name and folder path
mouse_name = "B2_M1_CTL"
mouse_folder = r"C:\Users\acart\Desktop\B2_M1_CTL"

# %%
# Initialize ImageJ
ij = imagej.init(r"C:\Users\acart\Documents\QUINT\Fiji", headless=False) # Path to FIJI installation FOLDER
print(f"ImageJ2 version: {ij.getVersion()}")

# Define the stitching macro
STITCHING_MACRO = """
#@ String grid_size_x
#@ String grid_size_y
#@ String tile_overlap
#@ String image_path
#@ String image_name
#@ String output_path
#@ String output_filename

run("Grid/Collection stitching",
    "type=[Grid: snake by rows] " +
    "order=[Right & Down                ] " +
    "grid_size_x=" + grid_size_x + " " +
    "grid_size_y=" + grid_size_y + " " +
    "tile_overlap=" + tile_overlap + " " +
    "first_file_index_i=1 " +
    "directory=[" + image_path + "] " +
    "file_names=" + image_name + " " +
    "output_textfile_name=TileConfiguration.txt " +
    "fusion_method=[Linear Blending] " +
    "regression_threshold=0.30 " +
    "max/avg_displacement_threshold=2.50 " +
    "absolute_displacement_threshold=3.50 " +
    "computation_parameters=[Save memory (but be slower)] " +
    "image_output=[Fuse and display]");

// Save the stitched image as TIF
selectWindow("Fused");
saveAs("Tiff", output_path + output_filename);
close();
"""

def stitch_images_with_imagej_macro(temp_folder, output_folder, grid_size_x, grid_size_y, tile_overlap, slice):
    """
    Stitch images using ImageJ Grid/Collection stitching plugin.
    
    Parameters:
    -----------
    temp_folder : str
        Directory containing the input images
    output_folder : str
        Directory where stitched image will be saved
    grid_size_x : int
        Number of columns in the grid
    grid_size_y : int
        Number of rows in the grid
    tile_overlap : int
        Percentage overlap between tiles (typically 10-30%) 
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Convert paths to forward slashes (ImageJ macro compatibility)
    temp_folder_macro = temp_folder.replace('\\', '/')
    output_folder_macro = output_folder.replace('\\', '/')
    
    # Ensure paths end with '/'
    if not temp_folder_macro.endswith('/'):
        temp_folder_macro += '/'
    if not output_folder_macro.endswith('/'):
        output_folder_macro += '/'
    
    # Prepare the macro arguments
    args = {
        "grid_size_x": str(grid_size_x),
        "grid_size_y": str(grid_size_y),
        "tile_overlap": str(tile_overlap),
        "image_path": temp_folder_macro,
        "image_name": f"Image_{slice}"+"_{iiiii}_Z001_Overlay.tif",
        "output_path": output_folder_macro,
        "output_filename": f"{mouse_name}_s{k}.tif"
    }
    
    print(f"Starting stitching with parameters:")
    print(f"  Grid size: {grid_size_x} x {grid_size_y}")
    print(f"  Tile overlap: {tile_overlap}%")
    print(f"  Input directory: {temp_folder_macro}")
    print(f"  Output directory: {output_folder_macro}")
    
    # Run the macro
    ij.py.run_macro(STITCHING_MACRO, args)
    print("Stitching complete!")
# Out:
# The headless flag of imagej.init is deprecated. Use the mode argument instead.
# ImageJ2 version: 2.16.0/1.54p

# %% [markdown]
# # **Stitching**

# %%
# Select all folders in the mouse folder
slide_list = os.listdir(mouse_folder)
# Filter out unwanted folders
slide_list = [s for s in slide_list if "Stitched" not in s and "coordinates" not in s]

# Load stitching coordinates
coordinates = pd.read_csv(os.path.join(mouse_folder,f"{mouse_name}_coordinates.csv"))
# Separate rows and columns
all_rows = coordinates.filter(regex = 'rows')
all_cols = coordinates.filter(regex = 'cols')

k=1
for i,slide in enumerate(slide_list):
    print(f"Processing slide {i+1} of {len(slide_list)}: {slide}")
    slices_list = os.listdir(os.path.join(mouse_folder,slide))
    for j,slice in enumerate(slices_list):
        
        print(f"  Processing slice {j+1} of {len(slices_list)}: {slice}")
        temp_folder = os.path.join(mouse_folder,slide,slice)
        output_folder = os.path.join(mouse_folder,"Stitched")
        
        # Select coordinates for current slide and slice
        col = all_cols.iloc[j,i]
        row = all_rows.iloc[j,i]
        stitch_images_with_imagej_macro(temp_folder, output_folder, grid_size_x=col, grid_size_y=row, tile_overlap=30, slice = slice)
        k+=1
# Out:
# Processing slide 1 of 3: S1_2
#   Processing slice 1 of 24: XY01
# Starting stitching with parameters:
#   Grid size: 13 x 13
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY01/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 2 of 24: XY02
# Starting stitching with parameters:
#   Grid size: 13 x 11
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY02/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 3 of 24: XY03
# Starting stitching with parameters:
#   Grid size: 14 x 12
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY03/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 4 of 24: XY04
# Starting stitching with parameters:
#   Grid size: 15 x 13
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY04/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 5 of 24: XY05
# Starting stitching with parameters:
#   Grid size: 15 x 14
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY05/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 6 of 24: XY06
# Starting stitching with parameters:
#   Grid size: 15 x 13
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY06/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 7 of 24: XY07
# Starting stitching with parameters:
#   Grid size: 16 x 14
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY07/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 8 of 24: XY08
# Starting stitching with parameters:
#   Grid size: 15 x 14
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY08/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 9 of 24: XY09
# Starting stitching with parameters:
#   Grid size: 16 x 14
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY09/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 10 of 24: XY10
# Starting stitching with parameters:
#   Grid size: 16 x 15
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY10/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 11 of 24: XY11
# Starting stitching with parameters:
#   Grid size: 16 x 15
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY11/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 12 of 24: XY12
# Starting stitching with parameters:
#   Grid size: 17 x 15
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY12/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 13 of 24: XY13
# Starting stitching with parameters:
#   Grid size: 17 x 16
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY13/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 14 of 24: XY14
# Starting stitching with parameters:
#   Grid size: 17 x 16
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY14/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 15 of 24: XY15
# Starting stitching with parameters:
#   Grid size: 18 x 16
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY15/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 16 of 24: XY16
# Starting stitching with parameters:
#   Grid size: 18 x 16
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY16/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 17 of 24: XY17
# Starting stitching with parameters:
#   Grid size: 18 x 16
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY17/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 18 of 24: XY18
# Starting stitching with parameters:
#   Grid size: 19 x 17
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY18/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 19 of 24: XY19
# Starting stitching with parameters:
#   Grid size: 19 x 17
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY19/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 20 of 24: XY20
# Starting stitching with parameters:
#   Grid size: 19 x 17
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY20/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 21 of 24: XY21
# Starting stitching with parameters:
#   Grid size: 19 x 16
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY21/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 22 of 24: XY22
# Starting stitching with parameters:
#   Grid size: 19 x 18
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY22/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 23 of 24: XY23
# Starting stitching with parameters:
#   Grid size: 19 x 18
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY23/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 24 of 24: XY24
# Starting stitching with parameters:
#   Grid size: 20 x 16
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S1_2/XY24/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
# Processing slide 2 of 3: S3_4
#   Processing slice 1 of 16: XY01
# Starting stitching with parameters:
#   Grid size: 20.0 x 18.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S3_4/XY01/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 2 of 16: XY02
# Starting stitching with parameters:
#   Grid size: 20.0 x 18.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S3_4/XY02/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 3 of 16: XY03
# Starting stitching with parameters:
#   Grid size: 20.0 x 18.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S3_4/XY03/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 4 of 16: XY04
# Starting stitching with parameters:
#   Grid size: 20.0 x 18.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S3_4/XY04/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 5 of 16: XY05
# Starting stitching with parameters:
#   Grid size: 20.0 x 18.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S3_4/XY05/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 6 of 16: XY06
# Starting stitching with parameters:
#   Grid size: 21.0 x 18.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S3_4/XY06/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 7 of 16: XY07
# Starting stitching with parameters:
#   Grid size: 13.0 x 18.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S3_4/XY07/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 8 of 16: XY08
# Starting stitching with parameters:
#   Grid size: 13.0 x 19.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S3_4/XY08/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 9 of 16: XY09
# Starting stitching with parameters:
#   Grid size: 21.0 x 19.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S3_4/XY09/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 10 of 16: XY10
# Starting stitching with parameters:
#   Grid size: 21.0 x 18.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S3_4/XY10/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 11 of 16: XY11
# Starting stitching with parameters:
#   Grid size: 21.0 x 19.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S3_4/XY11/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 12 of 16: XY12
# Starting stitching with parameters:
#   Grid size: 21.0 x 19.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S3_4/XY12/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 13 of 16: XY13
# Starting stitching with parameters:
#   Grid size: 22.0 x 19.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S3_4/XY13/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 14 of 16: XY14
# Starting stitching with parameters:
#   Grid size: 21.0 x 19.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S3_4/XY14/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 15 of 16: XY15
# Starting stitching with parameters:
#   Grid size: 10.0 x 15.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S3_4/XY15/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 16 of 16: XY16
# Starting stitching with parameters:
#   Grid size: 11.0 x 15.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S3_4/XY16/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
# Processing slide 3 of 3: S5_6
#   Processing slice 1 of 17: XY01
# Starting stitching with parameters:
#   Grid size: 22.0 x 18.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S5_6/XY01/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 2 of 17: XY02
# Starting stitching with parameters:
#   Grid size: 22.0 x 18.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S5_6/XY02/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 3 of 17: XY03
# Starting stitching with parameters:
#   Grid size: 22.0 x 17.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S5_6/XY03/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 4 of 17: XY04
# Starting stitching with parameters:
#   Grid size: 23.0 x 17.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S5_6/XY04/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 5 of 17: XY05
# Starting stitching with parameters:
#   Grid size: 21.0 x 18.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S5_6/XY05/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 6 of 17: XY06
# Starting stitching with parameters:
#   Grid size: 11.0 x 12.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S5_6/XY06/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 7 of 17: XY07
# Starting stitching with parameters:
#   Grid size: 4.0 x 10.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S5_6/XY07/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 8 of 17: XY08
# Starting stitching with parameters:
#   Grid size: 5.0 x 11.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S5_6/XY08/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 9 of 17: XY09
# Starting stitching with parameters:
#   Grid size: 10.0 x 15.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S5_6/XY09/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 10 of 17: XY10
# Starting stitching with parameters:
#   Grid size: 10.0 x 15.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S5_6/XY10/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 11 of 17: XY11
# Starting stitching with parameters:
#   Grid size: 10.0 x 15.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S5_6/XY11/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 12 of 17: XY12
# Starting stitching with parameters:
#   Grid size: 10.0 x 14.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S5_6/XY12/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 13 of 17: XY13
# Starting stitching with parameters:
#   Grid size: 10.0 x 15.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S5_6/XY13/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 14 of 17: XY14
# Starting stitching with parameters:
#   Grid size: 10.0 x 15.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S5_6/XY14/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 15 of 17: XY15
# Starting stitching with parameters:
#   Grid size: 10.0 x 15.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S5_6/XY15/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 16 of 17: XY16
# Starting stitching with parameters:
#   Grid size: 11.0 x 15.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S5_6/XY16/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!
#   Processing slice 17 of 17: XY17
# Starting stitching with parameters:
#   Grid size: 12.0 x 16.0
#   Tile overlap: 30%
#   Input directory: C:/Users/acart/Desktop/B2_M1_CTL/S5_6/XY17/
#   Output directory: C:/Users/acart/Desktop/B2_M1_CTL/Stitched/
# Stitching complete!

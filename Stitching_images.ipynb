# %% [markdown]
# # **Imports and Functions**

# %% [markdown]
# Notebook created by Antoine Carton-Leclercq, PhD
#
# *Tapper Lab, UMass Chan Medical School, Worcester MA*

# %%
import imagej
import os 
import pandas as pd

# Write down Mouse name and folder path
mouse_name = "B2_M2_CTL"
mouse_folder = r"E:\B2_M2_CTL"

# REPLACE WITH PREFIX CHOSEN WHEN SAVING ACQUIRED IMAGES Default = Image
prefix = 'Image'

# %% [markdown]
# Insert the path to the Fiji installation folder

# %%
# Initialize ImageJ
ij = imagej.init(r"E:\DATA\QUINT\fiji-latest-win64-jdk\Fiji", headless=False) # Path to FIJI installation FOLDER
print(f"ImageJ2 version: {ij.getVersion()}")

# Define the stitching macro
STITCHING_MACRO = """
#@ String grid_size_x
#@ String grid_size_y
#@ String tile_overlap
#@ String image_path
#@ String image_name
#@ String output_path
#@ String output_filename

run("Grid/Collection stitching",
    "type=[Grid: snake by rows] " +
    "order=[Right & Down                ] " +
    "grid_size_x=" + grid_size_x + " " +
    "grid_size_y=" + grid_size_y + " " +
    "tile_overlap=" + tile_overlap + " " +
    "first_file_index_i=1 " +
    "directory=[" + image_path + "] " +
    "file_names=" + image_name + " " +
    "output_textfile_name=TileConfiguration.txt " +
    "fusion_method=[Linear Blending] " +
    "regression_threshold=0.30 " +
    "max/avg_displacement_threshold=2.50 " +
    "absolute_displacement_threshold=3.50 " +
    "computation_parameters=[Save memory (but be slower)] " +
    "image_output=[Fuse and display]");

// Save the stitched image as TIF
selectWindow("Fused");
saveAs("Tiff", output_path + output_filename);
close();
"""

def stitch_images_with_imagej_macro(temp_folder, output_folder, grid_size_x, grid_size_y, tile_overlap, slice):
    """
    Stitch images using ImageJ Grid/Collection stitching plugin.
    
    Parameters:
    -----------
    temp_folder : str
        Directory containing the input images
    output_folder : str
        Directory where stitched image will be saved
    grid_size_x : int
        Number of columns in the grid
    grid_size_y : int
        Number of rows in the grid
    tile_overlap : int
        Percentage overlap between tiles (typically 10-30%) 
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Convert paths to forward slashes (ImageJ macro compatibility)
    temp_folder_macro = temp_folder.replace('\\', '/')
    output_folder_macro = output_folder.replace('\\', '/')
    
    # Ensure paths end with '/'
    if not temp_folder_macro.endswith('/'):
        temp_folder_macro += '/'
    if not output_folder_macro.endswith('/'):
        output_folder_macro += '/'
    
    # Prepare the macro arguments
    args = {
        "grid_size_x": str(grid_size_x),
        "grid_size_y": str(grid_size_y),
        "tile_overlap": str(tile_overlap),
        "image_path": temp_folder_macro,
        "image_name": f"{prefix}_{slice}"+"_{iiiii}_Z001_Overlay.tif",
        "output_path": output_folder_macro,
        "output_filename": f"{mouse_name}_s{k}.tif"
    }
    
    print(f"Starting stitching with parameters:")
    print(f"  Grid size: {grid_size_x} x {grid_size_y}")
    print(f"  Tile overlap: {tile_overlap}%")
    print(f"  Input directory: {temp_folder_macro}")
    print(f"  Output directory: {output_folder_macro}")
    
    # Run the macro
    ij.py.run_macro(STITCHING_MACRO, args)
    print("Stitching complete!")
# Out:
# The headless flag of imagej.init is deprecated. Use the mode argument instead.
# ImageJ2 version: 2.16.0/1.54p

# %% [markdown]
# # **Stitching**

# %%
# Select all folders in the mouse folder
slide_list = os.listdir(mouse_folder)
# Filter out unwanted folders
slide_list = [s for s in slide_list if "Stitched" not in s and "coordinates" not in s]

# Load stitching coordinates
coordinates = pd.read_csv(os.path.join(mouse_folder,f"{mouse_name}_coordinates.csv"), sep = ';')
# Separate rows and columns
all_rows = coordinates.filter(regex = 'rows')
all_cols = coordinates.filter(regex = 'cols')

k=1
for i,slide in enumerate(slide_list):
    print(f"Processing slide {i+1} of {len(slide_list)}: {slide}")
    slices_list = os.listdir(os.path.join(mouse_folder,slide))
    for j,slice in enumerate(slices_list):
        
        print(f"  Processing slice {j+1} of {len(slices_list)}: {slice}")
        temp_folder = os.path.join(mouse_folder,slide,slice)
        output_folder = os.path.join(mouse_folder,"Stitched")
        
        # Select coordinates for current slide and slice
        col = all_cols.iloc[j,i]
        row = all_rows.iloc[j,i]
        stitch_images_with_imagej_macro(temp_folder, output_folder, grid_size_x=col, grid_size_y=row, tile_overlap=30, slice = slice)
        k+=1
# Out:
# Processing slide 1 of 3: S1-2
#   Processing slice 1 of 30: XY01
# Starting stitching with parameters:
#   Grid size: 12 x 11
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY01/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 2 of 30: XY02
# Starting stitching with parameters:
#   Grid size: 13 x 11
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY02/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 3 of 30: XY03
# Starting stitching with parameters:
#   Grid size: 13 x 10
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY03/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 4 of 30: XY04
# Starting stitching with parameters:
#   Grid size: 14 x 13
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY04/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 5 of 30: XY05
# Starting stitching with parameters:
#   Grid size: 14 x 12
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY05/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 6 of 30: XY06
# Starting stitching with parameters:
#   Grid size: 14 x 12
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY06/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 7 of 30: XY07
# Starting stitching with parameters:
#   Grid size: 15 x 12
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY07/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 8 of 30: XY08
# Starting stitching with parameters:
#   Grid size: 15 x 12
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY08/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 9 of 30: XY09
# Starting stitching with parameters:
#   Grid size: 16 x 14
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY09/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 10 of 30: XY10
# Starting stitching with parameters:
#   Grid size: 16 x 13
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY10/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 11 of 30: XY11
# Starting stitching with parameters:
#   Grid size: 16 x 13
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY11/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 12 of 30: XY12
# Starting stitching with parameters:
#   Grid size: 17 x 14
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY12/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 13 of 30: XY13
# Starting stitching with parameters:
#   Grid size: 17 x 15
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY13/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 14 of 30: XY14
# Starting stitching with parameters:
#   Grid size: 17 x 15
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY14/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 15 of 30: XY15
# Starting stitching with parameters:
#   Grid size: 18 x 15
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY15/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 16 of 30: XY16
# Starting stitching with parameters:
#   Grid size: 18 x 15
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY16/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 17 of 30: XY17
# Starting stitching with parameters:
#   Grid size: 18 x 15
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY17/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 18 of 30: XY18
# Starting stitching with parameters:
#   Grid size: 19 x 15
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY18/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 19 of 30: XY19
# Starting stitching with parameters:
#   Grid size: 19 x 17
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY19/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 20 of 30: XY20
# Starting stitching with parameters:
#   Grid size: 19 x 18
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY20/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 21 of 30: XY21
# Starting stitching with parameters:
#   Grid size: 19 x 17
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY21/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 22 of 30: XY22
# Starting stitching with parameters:
#   Grid size: 20 x 17
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY22/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 23 of 30: XY23
# Starting stitching with parameters:
#   Grid size: 20 x 17
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY23/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 24 of 30: XY24
# Starting stitching with parameters:
#   Grid size: 20 x 18
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY24/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 25 of 30: XY25
# Starting stitching with parameters:
#   Grid size: 21 x 17
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY25/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 26 of 30: XY26
# Starting stitching with parameters:
#   Grid size: 20 x 17
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY26/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 27 of 30: XY27
# Starting stitching with parameters:
#   Grid size: 20 x 17
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY27/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 28 of 30: XY28
# Starting stitching with parameters:
#   Grid size: 21 x 18
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY28/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 29 of 30: XY29
# Starting stitching with parameters:
#   Grid size: 21 x 18
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY29/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 30 of 30: XY30
# Starting stitching with parameters:
#   Grid size: 21 x 17
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S1-2/XY30/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
# Processing slide 2 of 3: S3-4
#   Processing slice 1 of 18: XY01
# Starting stitching with parameters:
#   Grid size: 21.0 x 18.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S3-4/XY01/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 2 of 18: XY02
# Starting stitching with parameters:
#   Grid size: 21.0 x 19.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S3-4/XY02/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 3 of 18: XY03
# Starting stitching with parameters:
#   Grid size: 21.0 x 19.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S3-4/XY03/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 4 of 18: XY04
# Starting stitching with parameters:
#   Grid size: 21.0 x 18.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S3-4/XY04/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 5 of 18: XY05
# Starting stitching with parameters:
#   Grid size: 21.0 x 18.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S3-4/XY05/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 6 of 18: XY06
# Starting stitching with parameters:
#   Grid size: 21.0 x 19.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S3-4/XY06/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 7 of 18: XY07
# Starting stitching with parameters:
#   Grid size: 21.0 x 18.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S3-4/XY07/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 8 of 18: XY08
# Starting stitching with parameters:
#   Grid size: 21.0 x 18.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S3-4/XY08/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 9 of 18: XY09
# Starting stitching with parameters:
#   Grid size: 21.0 x 18.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S3-4/XY09/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 10 of 18: XY10
# Starting stitching with parameters:
#   Grid size: 21.0 x 18.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S3-4/XY10/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 11 of 18: XY11
# Starting stitching with parameters:
#   Grid size: 21.0 x 18.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S3-4/XY11/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 12 of 18: XY12
# Starting stitching with parameters:
#   Grid size: 21.0 x 18.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S3-4/XY12/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 13 of 18: XY13
# Starting stitching with parameters:
#   Grid size: 21.0 x 18.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S3-4/XY13/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 14 of 18: XY14
# Starting stitching with parameters:
#   Grid size: 21.0 x 19.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S3-4/XY14/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 15 of 18: XY15
# Starting stitching with parameters:
#   Grid size: 16.0 x 18.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S3-4/XY15/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 16 of 18: XY16
# Starting stitching with parameters:
#   Grid size: 22.0 x 18.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S3-4/XY16/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 17 of 18: XY17
# Starting stitching with parameters:
#   Grid size: 21.0 x 18.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S3-4/XY17/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 18 of 18: XY18
# Starting stitching with parameters:
#   Grid size: 20.0 x 17.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S3-4/XY18/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
# Processing slide 3 of 3: S5
#   Processing slice 1 of 8: XY01
# Starting stitching with parameters:
#   Grid size: 16.0 x 15.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S5/XY01/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 2 of 8: XY02
# Starting stitching with parameters:
#   Grid size: 16.0 x 15.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S5/XY02/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 3 of 8: XY03
# Starting stitching with parameters:
#   Grid size: 15.0 x 16.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S5/XY03/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 4 of 8: XY04
# Starting stitching with parameters:
#   Grid size: 10.0 x 14.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S5/XY04/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 5 of 8: XY05
# Starting stitching with parameters:
#   Grid size: 9.0 x 14.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S5/XY05/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 6 of 8: XY06
# Starting stitching with parameters:
#   Grid size: 10.0 x 14.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S5/XY06/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 7 of 8: XY07
# Starting stitching with parameters:
#   Grid size: 10.0 x 15.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S5/XY07/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
#   Processing slice 8 of 8: XY08
# Starting stitching with parameters:
#   Grid size: 10.0 x 15.0
#   Tile overlap: 30%
#   Input directory: E:/B1_F3_SFC/S5/XY08/
#   Output directory: E:/B1_F3_SFC/Stitched/
# Stitching complete!
